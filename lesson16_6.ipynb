# %%
import pandas as pd

dataFrame1 = pd.read_csv('學生成績表1.csv')
dataFrame1.index = dataFrame1['姓名']
dataFrame2 = dataFrame1[['國文','英文','數學','地理','歷史']]
dataFrame2
# Out:
#       國文   英文  數學   地理   歷史
# 姓名
# 葉志峰   67   61  73   82   64
# 彭茹靖   87   93  53   66   58
# 吳志宣   79   74  70   62   55
# 黃詩妃   68   97  76   93   86
# 陳向愛  100   96  56   51   90
# 張凱妮   93   93  55   60   59
# 張嘉韋   62   95  71   56   79
# 黃嘉琪   58   60  89   69   76
# 郭淑真   67   78  64   68   60
# 林佳光   55   85  98   97   77
# 高智超   65   65  81   69   79
# 張牧聿   58   52  66   61   89
# 溫重意   97   88  68   53   87
# 馬彥文   59   71  85   53   65
# 黃健發   55   84  98   86   87
# 陳淑娟   58  100  90   80   71
# 謝貞妃   62   67  98   98   81
# 李慶亮   84   98  97   89   53
# 吳淑惠   84   87  96   69   73
# 楊綺芬   95   85  59   50   57
# 張俊傑   71   78  66   94   75
# 林珍旺   53   82  72   79  100
# 郎慧萍   65   51  50   62   83
# 趙偉銘   86   82  58   56   71
# 游倫城   71   90  60   71   81
# 吳麗卿   58   94  55   72   72
# 艾巧夫  100   68  61   61   66
# 王泓泰   56   55  84   72   66
# 鄭奇翰   80   57  85   56   63
# 戴萱能   70   97  70   50  100
# 程玫靖   73   88  90   99   84
# 謝哲維   68   66  73   76   74
# 張伊映   98   64  82   80   81
# 吳欣書   95   92  86   91   55
# 藍哲嘉   68   74  91   73   85
# 林向鈺   72   80  69   53   55
# 陳淑娟   95   51  60   93   88
# 王雅慧   50   76  97   57   79
# 劉嘉泰   96   57  55   71   95
# 陳倩妮   61   71  95   73   97
# 藍哲嘉   84   51  99  100   65
# 呂傑宣   85   52  77   64   82
# 鍾俞禎   58   97  50   85   83
# 溫重意   57   50  58   91   57
# 鄭奇翰   73   66  75   62   87
# 魏秋萍   65   91  64   72   79
# 魏秋萍   79  100  71   92   64
# 李政成   66   64  95   60   57
# 張明惟   58   61  60   60   93
# 王雅慧   77   67  79   61   55

# %%
dataFrame2.loc['林佳光']
# Out:
# 國文    55
# 英文    85
# 數學    98
# 地理    97
# 歷史    77
# Name: 林佳光, dtype: int64

# %%
dataFrame2.loc[['林佳光']]
# Out:
#      國文  英文  數學  地理  歷史
# 姓名
# 林佳光  55  85  98  97  77

# %%
name1 = dataFrame2.loc[['林佳光']]
name1
# Out:
#      國文  英文  數學  地理  歷史
# 姓名
# 林佳光  55  85  98  97  77

# %%
name1.loc['林佳光'].sum()
sum = name1.loc['林佳光'].sum()
mean = name1.loc['林佳光'].mean()
name1['總分'] = sum
name1['平均'] = mean
name1
# Out:
#      國文  英文  數學  地理  歷史   總分    平均
# 姓名
# 林佳光  55  85  98  97  77  412  82.4

# %%
sum_s = dataFrame2.sum(axis=1)
mean_s = dataFrame2.sum(axis=1)
dataFrame2['總分'] = sum_s
dataFrame2['平均'] = mean_s
dataFrame2
# Out:
#       國文   英文  數學   地理   歷史    總分    平均
# 姓名
# 葉志峰   67   61  73   82   64  1041  1041
# 彭茹靖   87   93  53   66   58  1071  1071
# 吳志宣   79   74  70   62   55  1020  1020
# 黃詩妃   68   97  76   93   86  1260  1260
# 陳向愛  100   96  56   51   90  1179  1179
# 張凱妮   93   93  55   60   59  1080  1080
# 張嘉韋   62   95  71   56   79  1089  1089
# 黃嘉琪   58   60  89   69   76  1056  1056
# 郭淑真   67   78  64   68   60  1011  1011
# 林佳光   55   85  98   97   77  1236  1236
# 高智超   65   65  81   69   79  1077  1077
# 張牧聿   58   52  66   61   89   978   978
# 溫重意   97   88  68   53   87  1179  1179
# 馬彥文   59   71  85   53   65   999   999
# 黃健發   55   84  98   86   87  1230  1230
# 陳淑娟   58  100  90   80   71  1197  1197
# 謝貞妃   62   67  98   98   81  1218  1218
# 李慶亮   84   98  97   89   53  1263  1263
# 吳淑惠   84   87  96   69   73  1227  1227
# 楊綺芬   95   85  59   50   57  1038  1038
# 張俊傑   71   78  66   94   75  1152  1152
# 林珍旺   53   82  72   79  100  1158  1158
# 郎慧萍   65   51  50   62   83   933   933
# 趙偉銘   86   82  58   56   71  1059  1059
# 游倫城   71   90  60   71   81  1119  1119
# 吳麗卿   58   94  55   72   72  1053  1053
# 艾巧夫  100   68  61   61   66  1068  1068
# 王泓泰   56   55  84   72   66   999   999
# 鄭奇翰   80   57  85   56   63  1023  1023
# 戴萱能   70   97  70   50  100  1161  1161
# 程玫靖   73   88  90   99   84  1302  1302
# 謝哲維   68   66  73   76   74  1071  1071
# 張伊映   98   64  82   80   81  1215  1215
# 吳欣書   95   92  86   91   55  1257  1257
# 藍哲嘉   68   74  91   73   85  1173  1173
# 林向鈺   72   80  69   53   55   987   987
# 陳淑娟   95   51  60   93   88  1161  1161
# 王雅慧   50   76  97   57   79  1077  1077
# 劉嘉泰   96   57  55   71   95  1122  1122
# 陳倩妮   61   71  95   73   97  1191  1191
# 藍哲嘉   84   51  99  100   65  1197  1197
# 呂傑宣   85   52  77   64   82  1080  1080
# 鍾俞禎   58   97  50   85   83  1119  1119
# 溫重意   57   50  58   91   57   939   939
# 鄭奇翰   73   66  75   62   87  1089  1089
# 魏秋萍   65   91  64   72   79  1113  1113
# 魏秋萍   79  100  71   92   64  1218  1218
# 李政成   66   64  95   60   57  1026  1026
# 張明惟   58   61  60   60   93   996   996
# 王雅慧   77   67  79   61   55  1017  1017

# %%
dataFrame2.loc[['林佳光']]
# Out:
#      國文  英文  數學  地理  歷史    總分    平均
# 姓名
# 林佳光  55  85  98  97  77  1236  1236
