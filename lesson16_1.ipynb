# %%
#使用2維的list
#50個學生,每個學生的分數
import random
students = []
for j in range(50):
    scores = []
    for i in range(5):
        scores.append(random.randint(50,100))
    students.append(scores)

students
# Out:
# [[96, 63, 78, 79, 84],
#  [91, 54, 62, 90, 86],
#  [75, 75, 86, 64, 92],
#  [96, 72, 55, 72, 80],
#  [64, 65, 60, 68, 82],
#  [71, 100, 55, 100, 69],
#  [84, 59, 73, 85, 50],
#  [93, 97, 51, 53, 60],
#  [97, 86, 64, 92, 90],
#  [71, 50, 70, 55, 73],
#  [71, 55, 79, 91, 64],
#  [76, 71, 63, 97, 89],
#  [61, 70, 79, 96, 98],
#  [95, 91, 61, 74, 71],
#  [73, 100, 56, 92, 96],
#  [95, 82, 86, 100, 82],
#  [91, 80, 56, 90, 66],
#  [96, 87, 67, 91, 76],
#  [96, 97, 64, 63, 92],
#  [93, 76, 56, 71, 64],
#  [54, 100, 88, 78, 51],
#  [94, 76, 82, 60, 62],
#  [60, 72, 52, 58, 81],
#  [75, 54, 60, 55, 85],
#  [86, 86, 59, 61, 82],
#  [81, 96, 96, 56, 85],
#  [54, 87, 89, 61, 70],
#  [78, 71, 77, 62, 65],
#  [74, 88, 69, 74, 53],
#  [99, 92, 100, 75, 95],
#  [63, 51, 67, 65, 87],
#  [100, 98, 84, 51, 59],
#  [89, 77, 57, 73, 56],
#  [90, 70, 51, 93, 68],
#  [94, 73, 86, 100, 83],
#  [63, 90, 60, 54, 98],
#  [91, 84, 90, 93, 100],
#  [73, 94, 100, 68, 92],
#  [67, 64, 76, 90, 58],
#  [58, 81, 84, 75, 93],
#  [53, 83, 79, 87, 94],
#  [81, 71, 61, 79, 99],
#  [68, 98, 89, 51, 90],
#  [50, 77, 89, 77, 86],
#  [90, 64, 64, 50, 63],
#  [59, 70, 91, 59, 60],
#  [96, 56, 99, 92, 96],
#  [71, 67, 95, 76, 96],
#  [73, 75, 56, 92, 58],
#  [50, 76, 99, 81, 91]]

# %%
for student in students:
    total = 0
    for item in student:
        total += item
    print(total)
# Out:
# 400
# 383
# 392
# 375
# 339
# 395
# 351
# 354
# 429
# 319
# 360
# 396
# 404
# 392
# 417
# 445
# 383
# 417
# 412
# 360
# 371
# 374
# 323
# 329
# 374
# 414
# 361
# 353
# 358
# 461
# 333
# 392
# 352
# 372
# 436
# 365
# 458
# 427
# 355
# 391
# 396
# 391
# 396
# 379
# 331
# 339
# 439
# 405
# 354
# 397

# %%
import numpy as np

np.random.randint(50,high=101,size=(50,5))
# Out:
# array([[ 70,  70,  53,  65,  85],
#        [ 67,  85,  98,  98,  93],
#        [ 56,  76,  91,  71,  81],
#        [ 86,  92,  50,  99,  96],
#        [ 97,  71,  63,  78,  78],
#        [ 66,  51,  66,  84,  86],
#        [ 81,  76,  91,  65,  79],
#        [ 75,  74,  92,  95,  61],
#        [ 91,  61,  52,  73,  90],
#        [ 72,  55,  96,  54,  65],
#        [ 92,  62,  65,  80,  71],
#        [ 99,  65,  91,  78,  99],
#        [ 83,  71,  55,  82,  91],
#        [ 62,  61,  62,  59,  55],
#        [ 84,  66,  74,  63,  82],
#        [ 78,  94,  62,  69,  68],
#        [ 90,  71,  59,  63,  67],
#        [ 54,  84,  90,  56,  79],
#        [ 57,  60,  80,  62,  69],
#        [ 70,  82,  78,  52,  66],
#        [ 60,  83,  70,  73,  59],
#        [ 83,  94,  71,  84,  64],
#        [ 65,  96,  74,  82,  95],
#        [ 71,  50,  94,  65,  72],
#        [ 51,  78,  85,  95,  53],
#        [ 78,  96,  52,  67,  79],
#        [ 69,  79,  80,  96,  71],
#        [ 83,  92,  54,  59,  60],
#        [ 88,  66,  52,  67,  74],
#        [ 72,  58,  84,  74,  91],
#        [ 96,  79,  50,  83,  76],
#        [ 85,  79,  95,  69,  51],
#        [ 81,  92, 100,  87,  89],
#        [100,  56,  85,  61,  62],
#        [ 80,  67,  68,  74,  55],
#        [ 79,  52,  66,  84,  83],
#        [ 82,  70,  93,  73,  90],
#        [ 61,  83,  90,  63,  78],
#        [ 64,  79,  91,  94,  50],
#        [ 77,  57,  72,  73,  86],
#        [ 63,  71,  75,  78,  67],
#        [ 98,  74,  53,  94,  51],
#        [ 64,  55,  85,  66,  66],
#        [ 55,  63,  53,  75,  96],
#        [ 64,  54,  51,  66,  53],
#        [ 52,  63,  82,  53,  61],
#        [ 72,  94,  97,  76,  97],
#        [ 54,  88,  78,  84,  79],
#        [ 58,  65,  92,  84,  52],
#        [ 65,  56,  91,  60,  92]])

# %%
import numpy as np

scores = np.random.randint(50,high=101,size=(50,5))
sums = np.sum(scores,axis=1)
for student in sums:
    print(student)
# Out:
# 424
# 394
# 432
# 413
# 337
# 317
# 390
# 423
# 422
# 382
# 377
# 361
# 402
# 373
# 393
# 395
# 383
# 436
# 390
# 363
# 364
# 400
# 316
# 368
# 440
# 375
# 389
# 358
# 375
# 414
# 365
# 339
# 353
# 392
# 395
# 359
# 373
# 418
# 386
# 345
# 332
# 380
# 368
# 373
# 353
# 381
# 381
# 430
# 419
# 434

# %%
means = np.mean(scores,axis=1)
for student in sums:
    print(student)
# Out:
# 424
# 394
# 432
# 413
# 337
# 317
# 390
# 423
# 422
# 382
# 377
# 361
# 402
# 373
# 393
# 395
# 383
# 436
# 390
# 363
# 364
# 400
# 316
# 368
# 440
# 375
# 389
# 358
# 375
# 414
# 365
# 339
# 353
# 392
# 395
# 359
# 373
# 418
# 386
# 345
# 332
# 380
# 368
# 373
# 353
# 381
# 381
# 430
# 419
# 434

# %%
np.random.randint(50,high=101,size=(50,5))
# Out:
# array([[ 53,  96,  83,  81,  63],
#        [ 73,  81,  56,  72,  79],
#        [ 93,  88,  66,  78,  94],
#        [ 50,  61,  70,  53,  78],
#        [100,  55,  96,  82,  73],
#        [ 81,  73,  85,  70,  99],
#        [ 74,  66,  55,  53,  88],
#        [ 84,  80,  87,  81,  58],
#        [ 64,  99,  90,  60,  56],
#        [ 91,  82,  72,  79,  81],
#        [ 57,  59,  85,  96,  59],
#        [ 76,  60,  72,  88,  96],
#        [ 99,  58,  87,  58,  53],
#        [ 71,  65,  61,  78, 100],
#        [ 84,  64,  62,  95,  84],
#        [ 61,  56,  60,  64,  77],
#        [ 76,  96,  58,  92,  50],
#        [ 94,  71,  81,  61,  74],
#        [ 95,  66,  67,  71,  71],
#        [ 76,  63,  51,  98,  72],
#        [ 83,  86,  59,  85,  63],
#        [ 76,  76,  73,  97,  51],
#        [ 71,  51,  71,  78,  85],
#        [ 96,  86,  80,  56,  59],
#        [ 64,  72,  61,  80,  86],
#        [ 95,  51,  75,  94,  75],
#        [ 61,  69,  88,  85,  60],
#        [ 79,  50,  50,  91,  66],
#        [ 65,  87,  80,  82,  77],
#        [ 93,  60,  60,  52,  67],
#        [ 55,  57,  83,  90,  91],
#        [ 59,  85,  62,  83,  79],
#        [ 95,  79,  90,  63,  75],
#        [ 96,  89,  76,  67,  89],
#        [ 95,  96,  94,  80,  81],
#        [ 99,  68,  65,  65,  62],
#        [ 52,  78,  65,  66,  96],
#        [ 76,  58,  51,  87,  78],
#        [ 94,  91,  70,  99,  93],
#        [ 54,  76,  62,  65,  84],
#        [ 54,  71,  89,  59,  72],
#        [ 53,  87,  56,  72,  67],
#        [ 65,  83, 100,  61,  88],
#        [ 56,  50,  96,  63,  94],
#        [ 67,  81,  79,  71,  66],
#        [ 68,  78,  96,  59,  83],
#        [100,  68,  72,  56,  63],
#        [ 70,  78,  85,  97,  82],
#        [ 75,  87,  91,  57,  52],
#        [ 58,  61,  59,  79,  80]])
